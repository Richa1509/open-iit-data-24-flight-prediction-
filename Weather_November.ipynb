# %%
# !pip install meteostat

# %%
import pandas as pd
from meteostat import Point, Daily

# %%
df = pd.read_csv(r"/content/output_file_new.csv")

# %%
df['FlightDate'] = pd.to_datetime(df['FlightDate'])

# Function to get weather data using Meteostat
def get_weather_data(latitude, longitude, flight_date):
    location = Point(latitude, longitude)

    # Set the start and end date to the flight date
    start_date = flight_date
    end_date = flight_date

    # Fetch daily weather data
    data = Daily(location, start=start_date, end=end_date)
    weather_data = data.fetch()

    return weather_data

# Collect weather data
weather_results = []

# %%
df
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 0       2024        1      1          15          1 2024-01-15
# 1       2024        1      1          28          7 2024-01-28
# 2       2024        1      1           2          2 2024-01-02
# 3       2024        1      1           7          7 2024-01-07
# 4       2024        1      1          31          3 2024-01-31
# ...      ...      ...    ...         ...        ...        ...
# 529717  2022        4     12           7          3 2022-12-07
# 529718  2022        4     12           7          3 2022-12-07
# 529719  2022        4     12          12          1 2022-12-12
# 529720  2022        4     12          22          4 2022-12-22
# 529721  2022        4     12           4          7 2022-12-04
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 0                     B6                     20409
# 1                     AA                     19805
# 2                     WN                     19393
# ...

# %%
November_df = df[df['Month'] == 11]

# %%
November_df
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek FlightDate  \
# 293823  2023        4     11           9          4 2023-11-09
# 293824  2023        4     11          23          4 2023-11-23
# 293825  2023        4     11          24          5 2023-11-24
# 293826  2023        4     11          16          4 2023-11-16
# 293827  2023        4     11           7          2 2023-11-07
# ...      ...      ...    ...         ...        ...        ...
# 513004  2022        4     11          13          7 2022-11-13
# 513005  2022        4     11          21          1 2022-11-21
# 513006  2022        4     11           7          1 2022-11-07
# 513007  2022        4     11          26          6 2022-11-26
# 513008  2022        4     11          26          6 2022-11-26
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 293823                B6                     20409
# 293824                9E                     20363
# 293825                AA                     19805
# ...

# %%
for index, row in November_df.iterrows():
    latitude = row['Latitude']
    longitude = row['Longitude']
    flight_date = row['FlightDate']

    # Fetch weather data for the specified latitude, longitude, and flight date
    weather_data = get_weather_data(latitude, longitude, flight_date)

    # Append the weather data to the results list
    weather_results.append(weather_data)

# Convert the results into a single DataFrame for easier analysis
combined_weather_data = pd.concat(weather_results)

# Reset index if needed
combined_weather_data.reset_index(drop=True, inplace=True)

# Save the combined weather data to a CSV file
combined_weather_data.to_csv('/content/combined_weather_data.csv', index=False)

# Display the combined weather data
print(combined_weather_data)
# Out:
# ...
# ...
# ...
#        tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# 0       4.4   2.8   7.8   2.8   0.0  335.0   9.7   NaN  1014.1   0.0
# 1       8.2   1.7  15.0   0.0   0.0  271.0   4.7   NaN  1018.8   NaN
# 2       8.1   1.1  11.7   0.0   0.0  313.0  16.6   NaN  1021.7   NaN
# 3      13.1   7.8  20.0   0.0   0.0  260.0   8.2   NaN  1023.9   NaN
# 4      10.2   3.3  11.1   7.1   0.0  356.0  12.2   NaN  1013.8   NaN
# ...     ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 33200  24.8  20.6  31.1   0.0   0.0   21.0   5.0   NaN  1015.3   NaN
# 33201   8.8   1.7  16.1   0.0   0.0  320.0   5.7   NaN  1025.3   NaN
# 33202  19.3  16.7  21.1   4.3   0.0   55.0  11.5   NaN  1024.5   NaN
# 33203  12.1   8.9  13.3  30.7   0.0  279.0  11.2   NaN  1009.8   NaN
# 33204  10.1   7.0  14.0   0.0   0.0  291.0  11.4   NaN  1021.1   NaN
#
# [33205 rows x 10 columns]

# %%
for index, row in November_df.iterrows():
    latitude = row['Latitude']
    longitude = row['Longitude']
    flight_date = row['FlightDate']

    # Fetch weather data for the specified latitude, longitude, and flight date
    weather_data = get_weather_data(latitude, longitude, flight_date)

    # Append the weather data to the results list
    weather_results.append(weather_data)

# Convert the results into a single DataFrame for easier analysis
combined_weather_data = pd.concat(weather_results)

# Reset index if needed
combined_weather_data.reset_index(inplace=True)

# Display the combined weather data
print(combined_weather_data)
# Out:
# ...
# ...
# ...
#            index  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  \
# 0     2023-11-09   4.4   2.8   7.8   2.8   0.0  335.0   9.7   NaN  1014.1
# 1     2023-11-23   8.2   1.7  15.0   0.0   0.0  271.0   4.7   NaN  1018.8
# 2     2023-11-24   8.1   1.1  11.7   0.0   0.0  313.0  16.6   NaN  1021.7
# 3     2023-11-16  13.1   7.8  20.0   0.0   0.0  260.0   8.2   NaN  1023.9
# 4     2023-11-07  10.2   3.3  11.1   7.1   0.0  356.0  12.2   NaN  1013.8
# ...          ...   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 33200 2022-11-13  24.8  20.6  31.1   0.0   0.0   21.0   5.0   NaN  1015.3
# 33201 2022-11-21   8.8   1.7  16.1   0.0   0.0  320.0   5.7   NaN  1025.3
# 33202 2022-11-07  19.3  16.7  21.1   4.3   0.0   55.0  11.5   NaN  1024.5
# 33203 2022-11-26  12.1   8.9  13.3  30.7   0.0  279.0  11.2   NaN  1009.8
# 33204 2022-11-26  10.1   7.0  14.0   0.0   0.0  291.0  11.4   NaN  1021.1
#
#        tsun
# 0       0.0
# 1       NaN
# 2       NaN
# 3       NaN
# ...
